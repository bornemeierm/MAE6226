# %%
import numpy
from matplotlib import pyplot
# %matplotlib inline
import math

# %%
N = 360
r = 1.;

xc = numpy.zeros((1,N-1))
yc = numpy.zeros((1,N-1))

x_start, x_end = -3.0, 3.0                 # x-direction boundaries
y_start, y_end = -3.0, 3.0                 # y-direction boundaries
x = numpy.linspace(x_start, x_end, N-1)    # creates a 1D-array for x
y = numpy.linspace(y_start, y_end, N-1)    # creates a 1D-array for y
X, Y = numpy.meshgrid(x, y)                # generates a mesh gri

size = 10;

# %%
for i in range(N-1):
    xc[0,i] = r*numpy.cos(i)
    yc[0,i] = r*numpy.sin(i)

# %%
xc.shape
# Out:
# (1L, 359L)

# %%
pyplot.scatter(xc, yc, color='g', s=1, marker='o');
pyplot.axis('equal');
pyplot.grid(True);

# %%
z = xc+1j*yc + 1/(xc+1j*yc)

# %%
r = 1.5;

for i in range(N-1):
    xc[0,i] = r*numpy.cos(i)
    yc[0,i] = r*numpy.sin(i)

# %%
z = xc+1j*yc + 1/(xc+1j*yc)

# %%
pyplot.scatter(z.real, z.imag, color='r', s=1, marker='o');
pyplot.axis('equal');
pyplot.grid(True);

# %%
z = ((xc-.5)+1j*yc) + 1/((xc-.5)+1j*yc)

# %%
pyplot.scatter(z.real, z.imag, color='r', s=1, marker='o');
#pyplot.axis('equal');
pyplot.grid(True);
pyplot.xlim(-3,3);
pyplot.ylim(-3,3);

# %%
#streamplot, task number 4

# %%
for i in range(N-1):
    xc[0,i] = r*numpy.cos(i) - .5
    yc[0,i] = r*numpy.sin(i)
    
z = ((xc)+1j*yc) + 1/((xc)+1j*yc)    
pyplot.scatter(z.real, z.imag, color='r', s=1, marker='o');
#pyplot.axis('equal');
pyplot.grid(True);
pyplot.xlim(-3,3);
pyplot.ylim(-3,3);

# %%
u_inf = 1.0;

u_freestream = u_inf * numpy.ones((N-1,N-1), dtype=float);
v_freestream = numpy.zeros((N-1,N-1), dtype=float);

psi_freestream = u_inf * Y;

# %%
kappa = r**2*2*numpy.pi*u_inf;

# %%
def get_velocity_doublet(strength, xd, yd, X, Y):
    """Returns the velocity field generated by a doublet.
    
    Arguments
    ---------
    strength -- strength of the doublet.
    xd, yd -- coordinates of the doublet.
    X, Y -- mesh grid.
    """
    u = - strength/(2*numpy.pi)*((X-xd)**2-(Y-yd)**2)/((X-xd)**2+(Y-yd)**2)**2
    v = - strength/(2*numpy.pi)*2*(X-xd)*(Y-yd)/((X-xd)**2+(Y-yd)**2)**2
    
    return u, v

def get_stream_function_doublet(strength, xd, yd, X, Y):
    """Returns the stream-function generated by a doublet.
    
    Arguments
    ---------
    strength -- strength of the doublet.
    xd, yd -- coordinates of the doublet.
    X, Y -- mesh grid.
    """
    psi = - strength/(2*numpy.pi)*(Y-yd)/((X-xd)**2+(Y-yd)**2)
    
    return psi

# %%
# computes the velocity field on the mesh grid
u_cyl, v_cyl = get_velocity_doublet(kappa, -.5, 0, X, Y)

psi_cyl = get_stream_function_doublet(kappa, -.5, 0, X, Y)

# %%
u_total = u_freestream + u_cyl;
v_total = v_freestream + v_cyl;
psi_total = psi_cyl + psi_freestream

zgrid = (X+1j*Y) + 1/((X+1j*Y));
 
pyplot.scatter(zgrid.real,zgrid.imag);
pyplot.xlim(-3,3);
pyplot.ylim(-3,3);

# %%
pyplot.contour(zgrid.real,zgrid.imag,psi_total,levels=numpy.linspace(numpy.min(psi_total),numpy.max(psi_total),100),linewidths=2,linestyles='solid');
pyplot.scatter(z.real,z.imag,color='#CD2305',s=10,marker='o');
pyplot.xlim(-6,3);
pyplot.ylim(-6,3);
